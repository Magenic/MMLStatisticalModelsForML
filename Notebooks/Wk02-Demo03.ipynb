# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
import random
import numpy as np
import gc
import math

TOTAL_DATA_POINTS = 200
N_HIDDEN = 512
RESHAPED = 2
NB_CLASSES = 4
DROPOUT = 0.3
BATCH_SIZE = 15
EPOCHS = 15
VERBOSE = 1
VALIDATION_SPLIT = 0.25
TOTAL_ITEMS = 4

def get_dataset():
    rng = tf.random.Generator.from_seed(seed=234)
    randomNumbers = rng.truncated_normal(shape=[TOTAL_DATA_POINTS], mean=0.5, stddev=.05)
    return randomNumbers

random_dataset = get_dataset()

def get_random_numbers():
    randomNumbers = []
    for i in range(0, TOTAL_DATA_POINTS):
        randomNumbers.append(random.random())
    return randomNumbers

random_dataset = get_dataset()

random_numbers = get_random_numbers()

def convert_to_train_test_data(random_dataset, random_numbers, test_percent = 0.15, sparse = False):
    total_independent = []
    total_dependent = []
    
    for i in range(0, TOTAL_DATA_POINTS):
        index = getIndex(random_numbers[i])
        total_dependent.append(getArrayFromIndex(index, sparse))
    
    count = 0
    for i in total_dependent:
        index = getIndexFromArray(i, sparse)
        total_independent.append([random_dataset[count].numpy() / (index + 1), random_dataset[count].numpy() ** (index + 1)])
        count = count + 1
            
    testRecordCount = int(round(test_percent*len(total_independent)))
    return total_independent[testRecordCount:], total_dependent[testRecordCount:], total_independent[:testRecordCount], total_dependent[:testRecordCount]
    
def getIndex(chance):
    return math.ceil(chance * TOTAL_ITEMS)

def getIndexFromArray(array, sparse = False):
    if (sparse == True):
        return array
    else:
        return np.where(array == np.amax(array))[0][0] + 1


def getArrayFromIndex(index, sparse = False):
    if (sparse == True):
        return index - 1
    else:
        return [1 if index == 1 else 0, 1 if index == 2 else 0, 1 if index == 3 else 0, 1 if index == 4 else 0]

def createModel(lossFunction):

    model = tf.keras.models.Sequential()
    model.add(keras.layers.Input(shape=(RESHAPED,)))
    model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_dense_layer', activation='relu'))
    model.add(keras.layers.Dropout(DROPOUT))
    model.add(keras.layers.Dense(N_HIDDEN, name='hidden_dense_layer', activation='relu'))
    model.add(keras.layers.Dropout(DROPOUT))
    model.add(keras.layers.Activation(activation='selu'))
    model.add(keras.layers.Dense(NB_CLASSES, activation='softmax', name='output_dense_layer'))
    model.compile(optimizer='adam', loss=lossFunction, metrics=['accuracy'])
    
    return model

def displayResults(history):
    train_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    epochs = range(1, len(validation_loss)+1)

    fig, ax = plt.subplots()  # Create a figure and an axes.
    ax.plot(epochs, train_loss, label='train loss')
    ax.plot(epochs, validation_loss, label='validation loss')
    ax.set_xlabel('epoch')  # Add an x-label to the axes.
    ax.set_ylabel('loss')  # Add a y-label to the axes.
    ax.set_title("Simple Plot")  # Add a title to the axes.
    ax.legend() 

def showPrediction(model, x_train, y_train, x_test, y_test, sparse = False):

    INDEX_1 = 0
    INDEX_2 = 1
    TRAINING_X_1 = []
    TRAINING_X_2 = []
    TRAINING_Y = []
    TEST_X_1 = []
    TEST_X_2 = []
    TEST_Y = []
    PREDICTED_INDEPENDANT_1 = []
    PREDICTED_INDEPENDANT_2 = []
    PREDICTED_DEPENDANT = []

    count = 0
    for p in y_train:
        TRAINING_X_1.append(x_train[count][INDEX_1])
        TRAINING_X_2.append(x_train[count][INDEX_2])
        if sparse == True:
            TRAINING_Y.append(y_train[count] + 1)
        else:
            TRAINING_Y.append(getIndexFromArray(y_train[count]))
        count += 1
        
    count = 0
    for p in y_test:
        TEST_X_1.append(x_test[count][INDEX_1])
        TEST_X_2.append(x_test[count][INDEX_2])
        if sparse == True:
            TEST_Y.append(y_test[count] + 1)
        else:
            TEST_Y.append(getIndexFromArray(y_test[count]))
        count += 1
    
    pred_traning = model.predict(np.array(x_train))

    count = 0
    for p in pred_traning:
        PREDICTED_INDEPENDANT_1.append(x_train[count][INDEX_1])
        PREDICTED_INDEPENDANT_2.append(x_train[count][INDEX_2])
        PREDICTED_DEPENDANT.append(getIndexFromArray(p))
        count += 1

    pred_validation = model.predict(np.array(x_test))

    count = 0
    for p in pred_validation:
        PREDICTED_INDEPENDANT_1.append(x_test[count][INDEX_1])
        PREDICTED_INDEPENDANT_2.append(x_test[count][INDEX_2])
        PREDICTED_DEPENDANT.append(getIndexFromArray(p))
        count += 1

    fig, ax = plt.subplots()  # Create a figure and an axes.
    ax.plot(TRAINING_X_1, TRAINING_Y, label='training data', linewidth=0, marker='.')
    ax.plot(TEST_X_1, TEST_Y, label='test data', linewidth=0, marker='.')
    ax.set_xlabel('independent')  # Add an x-label to the axes.
    ax.set_ylabel('dependant')  # Add a y-label to the axes.
    ax.legend() 
    
    fig, ax = plt.subplots()  # Create a figure and an axes.
    ax.plot(PREDICTED_INDEPENDANT_1, PREDICTED_DEPENDANT, label='prediction values', linewidth=0, marker='.')
    ax.set_xlabel('independent')  # Add an x-label to the axes.
    ax.set_ylabel('dependant')  # Add a y-label to the axes.
    ax.legend() 
    
    fig, ax = plt.subplots()  # Create a figure and an axes.
    ax.plot(TRAINING_X_2, TRAINING_Y, label='training data', linewidth=0, marker='.')
    ax.plot(TEST_X_2, TEST_Y, label='test data', linewidth=0, marker='.')
    ax.set_xlabel('independent')  # Add an x-label to the axes.
    ax.set_ylabel('dependant')  # Add a y-label to the axes.
    ax.legend() 
    
    fig, ax = plt.subplots()  # Create a figure and an axes.
    ax.plot(PREDICTED_INDEPENDANT_2, PREDICTED_DEPENDANT, label='prediction values', linewidth=0, marker='.')
    ax.set_xlabel('independent')  # Add an x-label to the axes.
    ax.set_ylabel('dependant')  # Add a y-label to the axes.
    ax.legend() 

print('done')
# Out:
# done

# %%
tf.random.set_seed(1234)
np.random.seed(0)
tf.random.shuffle(tf.range(5))
    
x_train, y_train, x_test, y_test = convert_to_train_test_data(random_dataset, random_numbers, test_percent=0.15, sparse=False)

model = createModel('categorical_crossentropy')

history = model.fit(np.array(x_train), np.array(y_train), batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(np.array(x_test), np.array(y_test))
print()
print('Test accuracy:', test_acc)

displayResults(history)

showPrediction(model, x_train, y_train, x_test, y_test)

del model
tf.keras.backend.clear_session()

gc.collect()
# Out:
# Epoch 1/15
# 9/9 [==============================] - 1s 61ms/step - loss: 1.3715 - accuracy: 0.2992 - val_loss: 1.3565 - val_accuracy: 0.1628
# Epoch 2/15
# 9/9 [==============================] - 0s 15ms/step - loss: 1.3230 - accuracy: 0.3622 - val_loss: 1.3127 - val_accuracy: 0.3023
# Epoch 3/15
# 9/9 [==============================] - 0s 16ms/step - loss: 1.2511 - accuracy: 0.4409 - val_loss: 1.2157 - val_accuracy: 0.3953
# Epoch 4/15
# 9/9 [==============================] - 0s 18ms/step - loss: 1.1539 - accuracy: 0.4882 - val_loss: 1.1123 - val_accuracy: 0.3953
# Epoch 5/15
# 9/9 [==============================] - 0s 18ms/step - loss: 1.0514 - accuracy: 0.5512 - val_loss: 0.9916 - val_accuracy: 0.5581
# Epoch 6/15
# 9/9 [==============================] - 0s 17ms/step - loss: 0.9399 - accuracy: 0.7087 - val_loss: 0.8737 - val_accuracy: 0.7209
# Epoch 7/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.8408 - accuracy: 0.7559 - val_loss: 0.7582 - val_accuracy: 0.8372
# Epoch 8/15
# 9/9 [==============================] - 0s 15ms/step - loss: 0.7481 - accuracy: 0.8110 - val_loss: 0.7086 - val_accuracy: 0.7674
# Epoch 9/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6800 - accuracy: 0.7795 - val_loss: 0.6281 - val_accuracy: 0.8605
# Epoch 10/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6301 - accuracy: 0.7717 - val_loss: 0.5641 - val_accuracy: 0.8372
# Epoch 11/15
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5737 - accuracy: 0.7795 - val_loss: 0.5600 - val_accuracy: 0.7674
# Epoch 12/15
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5498 - accuracy: 0.8031 - val_loss: 0.5302 - val_accuracy: 0.8140
# Epoch 13/15
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5269 - accuracy: 0.8031 - val_loss: 0.4968 - val_accuracy: 0.7907
# Epoch 14/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4918 - accuracy: 0.8031 - val_loss: 0.4938 - val_accuracy: 0.8140
# Epoch 15/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5083 - accuracy: 0.8189 - val_loss: 0.5167 - val_accuracy: 0.7674
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.8333
#
# Test accuracy: 0.8333333134651184
# 2818

# %%
tf.random.set_seed(1234)
np.random.seed(0)
tf.random.shuffle(tf.range(5))

x_train, y_train, x_test, y_test = convert_to_train_test_data(random_dataset, random_numbers, test_percent=0.15, sparse=True)
    
model = createModel('sparse_categorical_crossentropy')

history = model.fit(np.array(x_train), np.array(y_train), batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(np.array(x_test), np.array(y_test))
print()
print('Test accuracy:', test_acc)

displayResults(history)

showPrediction(model, x_train, y_train, x_test, y_test, sparse=True)

del model
tf.keras.backend.clear_session()

gc.collect()
# Out:
# Epoch 1/15
# 9/9 [==============================] - 0s 43ms/step - loss: 1.3605 - accuracy: 0.3071 - val_loss: 1.3075 - val_accuracy: 0.3256
# Epoch 2/15
# 9/9 [==============================] - 0s 16ms/step - loss: 1.2763 - accuracy: 0.2835 - val_loss: 1.2138 - val_accuracy: 0.3023
# Epoch 3/15
# 9/9 [==============================] - 0s 16ms/step - loss: 1.1744 - accuracy: 0.3071 - val_loss: 1.0804 - val_accuracy: 0.6047
# Epoch 4/15
# 9/9 [==============================] - 0s 17ms/step - loss: 1.0550 - accuracy: 0.5984 - val_loss: 0.9591 - val_accuracy: 0.7209
# Epoch 5/15
# 9/9 [==============================] - 0s 17ms/step - loss: 0.9360 - accuracy: 0.7559 - val_loss: 0.8287 - val_accuracy: 0.8837
# Epoch 6/15
# 9/9 [==============================] - 0s 15ms/step - loss: 0.8033 - accuracy: 0.8583 - val_loss: 0.6971 - val_accuracy: 0.9070
# Epoch 7/15
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6762 - accuracy: 0.9134 - val_loss: 0.5762 - val_accuracy: 0.9302
# Epoch 8/15
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5634 - accuracy: 0.9291 - val_loss: 0.4986 - val_accuracy: 0.8837
# Epoch 9/15
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4796 - accuracy: 0.9055 - val_loss: 0.4143 - val_accuracy: 0.9302
# Epoch 10/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4093 - accuracy: 0.9055 - val_loss: 0.3502 - val_accuracy: 0.9302
# Epoch 11/15
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3507 - accuracy: 0.9291 - val_loss: 0.3440 - val_accuracy: 0.8837
# Epoch 12/15
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3263 - accuracy: 0.8976 - val_loss: 0.2811 - val_accuracy: 0.9302
# Epoch 13/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2970 - accuracy: 0.9134 - val_loss: 0.2759 - val_accuracy: 0.9302
# Epoch 14/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2640 - accuracy: 0.9449 - val_loss: 0.2544 - val_accuracy: 0.9535
# Epoch 15/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2786 - accuracy: 0.9055 - val_loss: 0.2481 - val_accuracy: 0.9302
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2029 - accuracy: 0.9333
#
# Test accuracy: 0.9333333373069763
# 24573

# %%
tf.random.set_seed(1234)
np.random.seed(0)
tf.random.shuffle(tf.range(5))

x_train, y_train, x_test, y_test = convert_to_train_test_data(random_dataset, random_numbers, test_percent=0.15, sparse=False)
    
model = createModel('KLDivergence')

history = model.fit(np.array(x_train), np.array(y_train), batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

test_loss, test_acc = model.evaluate(np.array(x_test), np.array(y_test))
print()
print('Test accuracy:', test_acc)

displayResults(history)

showPrediction(model, x_train, y_train, x_test, y_test)

del model
tf.keras.backend.clear_session()

gc.collect()
# Out:
# Epoch 1/15
# 9/9 [==============================] - 0s 40ms/step - loss: 1.3715 - accuracy: 0.2992 - val_loss: 1.3565 - val_accuracy: 0.1628
# Epoch 2/15
# 9/9 [==============================] - 0s 17ms/step - loss: 1.3230 - accuracy: 0.3622 - val_loss: 1.3127 - val_accuracy: 0.3023
# Epoch 3/15
# 9/9 [==============================] - 0s 16ms/step - loss: 1.2511 - accuracy: 0.4409 - val_loss: 1.2157 - val_accuracy: 0.3953
# Epoch 4/15
# 9/9 [==============================] - 0s 16ms/step - loss: 1.1538 - accuracy: 0.4882 - val_loss: 1.1123 - val_accuracy: 0.3953
# Epoch 5/15
# 9/9 [==============================] - 0s 18ms/step - loss: 1.0514 - accuracy: 0.5512 - val_loss: 0.9915 - val_accuracy: 0.5581
# Epoch 6/15
# 9/9 [==============================] - 0s 17ms/step - loss: 0.9399 - accuracy: 0.7087 - val_loss: 0.8737 - val_accuracy: 0.7209
# Epoch 7/15
# 9/9 [==============================] - 0s 19ms/step - loss: 0.8408 - accuracy: 0.7559 - val_loss: 0.7582 - val_accuracy: 0.8372
# Epoch 8/15
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7481 - accuracy: 0.8110 - val_loss: 0.7086 - val_accuracy: 0.7674
# Epoch 9/15
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6800 - accuracy: 0.7795 - val_loss: 0.6281 - val_accuracy: 0.8605
# Epoch 10/15
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6301 - accuracy: 0.7717 - val_loss: 0.5641 - val_accuracy: 0.8372
# Epoch 11/15
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5736 - accuracy: 0.7795 - val_loss: 0.5600 - val_accuracy: 0.7674
# Epoch 12/15
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5498 - accuracy: 0.8031 - val_loss: 0.5302 - val_accuracy: 0.8140
# Epoch 13/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5269 - accuracy: 0.8031 - val_loss: 0.4968 - val_accuracy: 0.7907
# Epoch 14/15
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4918 - accuracy: 0.8031 - val_loss: 0.4938 - val_accuracy: 0.8140
# Epoch 15/15
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5083 - accuracy: 0.8189 - val_loss: 0.5166 - val_accuracy: 0.7674
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.8333
#
# Test accuracy: 0.8333333134651184
# 24044
